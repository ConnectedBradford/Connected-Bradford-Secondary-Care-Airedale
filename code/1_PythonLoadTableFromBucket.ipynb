# %%
from google.cloud import bigquery
from google.cloud.bigquery import LoadJobConfig
from google.cloud.bigquery import SchemaField

client = bigquery.Client()
dataset_ref = client.dataset('CB_MYSPACE_JDB')
# Out:
# /opt/conda/lib/python3.7/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.7/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
#### Create the table src_SUS_Airedale_OP_20220601_to_Current

schema = [
bigquery.SchemaField('pkid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primrec', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('copyrec1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('copyrec2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('copyrec3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('copyrec4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('copyrec5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('translatortype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdsgroup', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rectype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdsversionno', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdsident', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('testind', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('updatetype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('updateprot', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('updateprotid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdsactivitydate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulkstart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulkend', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dttmcreated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purch', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('servlin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commref', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhsnostts', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nameformat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('addressformat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surname', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('forename', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ha', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('carer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dob', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethncorg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnic_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reggp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('regprac', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('localpatid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referrer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('refprac', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('servtype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('datereq', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('refprty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('refsrc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mainspec', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('trtspec', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('localspec', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinicpur', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attident', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admcat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('loctype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sitecode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('medstaff', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('appdate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('apptype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('appsts', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attended', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('appoutcm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lastdnadate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('apptime', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ageatcds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('earliestoffer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fundtype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('priicd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('subicd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('firsticd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiag13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readver', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('priread0', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('subread', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('firstread', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secdiaread13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('opstatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc1date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc2date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc3date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc4date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc5date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc6date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc7date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc8date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc9date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc10date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc11date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proc12date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readverind', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('priread', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prireaddate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readdate12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('userfield1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('userfield2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('userfield3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('userfield4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('contractid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrgcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrgver', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('localsubspec', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hdgvp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrgopcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cliniccode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('wardcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('providerrefno', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('invoicenumber', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('price', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('contractcategory', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primlocopproc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a1stseclocopproc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2ndseclocopproc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2ndseclocdiag', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('localpatidorg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ubrnc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ppid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgpathid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rttstatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rttstartdate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rttenddate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('osicnt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('osicd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('osrcnt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ocrd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pcopcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prsopcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pccnt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prsread', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgres', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('multipro', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rehass', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consmed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diracc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presentonadmissionindicatorcount', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presadm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proregistmainopcount', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professionalregistrationmainoperator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('proregistrespanaecount', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professionalregistrationresponsibleanaesthetist', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('waitmeas', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('earclin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('withheld', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('subspec', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('apptime_v2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('expdur', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ovscls', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cliniccode2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('datasetref', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('src_SUS_Airedale_OP_20220601_to_Current')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for src_DemoGraphics_MASTER

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/src_SUS_Airedale_OP_20220601_to_Current.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# Loaded 763322 rows.

# %%
## Create the table src_SUS_Airedale_ECDS_20220601_to_Current

schema = [
bigquery.SchemaField('pkid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pr', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('update_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('protocol_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_activity_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulkstart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulkend', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_created', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_created', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('withheld', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_no_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('locpatid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('local_patient_id_org', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surname', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('forename', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccgofres', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dob', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnic_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethcat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acc_status_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pref_lang_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('access_info_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intp_lang_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ovs_charging', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gpreg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pracreg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sittrt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('depttype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ambinc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgamb', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrmode_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_src_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_orgcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_at_cds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assess_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assess_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acuity_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('chief_complaint_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treat_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treat_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('serial_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cont_line_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider_ref_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purchaser_ref', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('comm_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('invest_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('invest_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treat_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treat_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ubrn', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ppi', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ocppii', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtps', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('waitmeas', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtpsd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtped', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mental_health_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mental_health_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_place_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_lat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_long', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_intent_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_act_status_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_act_type_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_mechanism_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_alcoholdrug_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_alcoholdrug_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('comorbidity_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('comorbidity_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('care_prof_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('care_pro_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ref_otherservices_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ref_otherservices', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('decto_admit_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('decto_admit_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('activity_treat_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disch_status_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('conclusion_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('conclusion_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('depart_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('depart_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('safeguarding_concern_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('safeguarding_concern', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disch_dest_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disch_orgcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disch_followup_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disch_info_gvn_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinical_trial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disease_outbreak', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disease_outbreak_snmdct', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('care_contct_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exptd_trt_dt_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exptd_trt_dt_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('coded_scored_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('coded_scored_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('coded_obs_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('coded_obs_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('coded_finding_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('coded_finding_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clin_ready_to_prcd_timstamp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnic_2021', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assault_loc_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('datasetref', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('src_SUS_Airedale_ECDS_20220601_to_Current')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for src_DemoGraphics_MASTER

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/src_SUS_Airedale_ECDS_20220601_to_Current.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# Loaded 117108 rows.

# %%
## Create the table src_SUS_Airedale_APC_20220601_to_Current

schema = [
  bigquery.SchemaField('pkid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pr', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cr5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('translator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('recordtype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdsgroup', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdstype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdsversionnumber', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('testflag', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('updatetype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('protocolind', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('protocolid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulkstart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulkend', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_activity_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('datetimecreated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prov', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purch', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('serialno', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('contractline', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purchref', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nnn_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nameformat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('addrformat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surname', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('forename', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeadd5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ha', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mstatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('carer_support_ind', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dob', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reg_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reg_gp_prac', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnc_nhscode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnic_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referrer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reforg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provspno', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admin_cat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('legalstatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('elecdate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admdate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admeth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('elecdur', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('man_intent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('earliest_res_offer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admsrce', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admage', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dischdate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dismeth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disreadydate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('disdes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patclass', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ep_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_in_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('epistart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('epiend', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sitecode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('speccode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('conspec', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('subspec', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('conscode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homesite', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('startsite', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('endsite', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('startward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('endward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('healthsite', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('healthstart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('healthend', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homestart', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('homeend', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('epidur', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('epistat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_reg_adm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neonatal_level', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admistat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdsage', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diag14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('readversion', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operstatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op1date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op2date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op3date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op4date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op5date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op6date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op7date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op8date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op9date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op10date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op11date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op12date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('read_version', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op1_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op2_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op3_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op4_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op5_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op6_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op7_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op8_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op9_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op10_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op11_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op12_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op1_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op2_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op3_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op4_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op5_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op6_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op7_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op8_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op9_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op10_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op11_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op12_read_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('antenatalgp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('antenatalgpprac', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anteassessdate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('numpreg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delplace', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('deldate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delinten', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delchange', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delonset', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delmeth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delstat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delprean', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delposan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mumdob', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('numbaby', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sexbaby1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birord1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birstat1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birweit1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('biresus1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('babydob1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sexbaby2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birord2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birstat2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birweit2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('biresus2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('babydob2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sexbaby3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birord3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birstat3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birweit3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('biresus3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('babydob3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sexbaby4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birord4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birstat4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birweit4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('biresus4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('babydob4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sexbaby5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birord5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birstat5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birweit5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('biresus5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('babydob5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sexbaby6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birord6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birstat6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birweit6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('biresus6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('babydob6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('user_field_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('user_field_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('user_field_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('user_field_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('waiting_list_priority', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_on_wl_orig', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('contract_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_ver', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('local_specialty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hdgvp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delmethod1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delmethod2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delmethod3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delmethod4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delmethod5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delmethod6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('statpersondel1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('statpersondel2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('statpersondel3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('statpersondel4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('statpersondel5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('statpersondel6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('locpatid1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('locpatid2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('locpatid3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('locpatid4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('locpatid5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('locpatid6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgcodebaby1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgcodebaby2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgcodebaby3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgcodebaby4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgcodebaby5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orgcodebaby6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestnobaby1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestbaby1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestbaby2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestnobaby2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestnobaby3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestbaby3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestbaby4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestnobaby4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestnobaby5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestbaby5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestbaby6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digestnobaby6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhsnostat1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhsnostat2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhsnostat3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhsnostat4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhsnostat5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhsnostat6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclocalid1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccstartdate1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccunitfunction1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arsd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('brsd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acsd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bcsd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rsd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nssd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dssd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lsd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclevel2_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclevel3_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischdate1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccstarttime1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unitbedconfig1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adsource1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adsourceloc1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adtype1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gsd1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maxos1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischtime1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischreadydate1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischreadytime1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischstatus1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdisdest1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdisloc1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclocalid2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccstartdate2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccunitfunction2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arsd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('brsd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acsd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bcsd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rsd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nssd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dssd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lsd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclevel2_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclevel3_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischdate2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccstarttime2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unitbedconfig2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adsource2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adsourceloc2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adtype2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gsd2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maxos2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischtime2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischreadydate2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischreadytime2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischstatus2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdisdest2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdisloc2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclocalid3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccstartdate3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccunitfunction3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arsd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('brsd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acsd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bcsd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rsd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nssd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dssd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lsd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclevel2_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cclevel3_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischdate3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccstarttime3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unitbedconfig3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adsource3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adsourceloc3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adtype3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gsd3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maxos3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischtime3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischreadydate3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischreadytime3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdischstatus3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdisdest3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccdisloc3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f359', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f360', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f361', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f362', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f363', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f364', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f365', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f366', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f367', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f368', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f369', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f370', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f371', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f372', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f373', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f374', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f375', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f376', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f377', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f378', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f379', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f380', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f381', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f382', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f383', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f384', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f385', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f386', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f387', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f388', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f389', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f390', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f391', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f392', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f393', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f394', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f395', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f396', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f397', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f398', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f399', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f400', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f401', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f402', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f403', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f404', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f405', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f406', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f407', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f408', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f409', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f410', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f411', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f412', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f413', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f414', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f415', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f416', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f417', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f418', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f419', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f420', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f421', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f422', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f423', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f424', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f425', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f426', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f427', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f428', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f429', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f430', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f431', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f432', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f433', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f434', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f435', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f436', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f437', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f438', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f439', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f440', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f441', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f442', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f443', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f444', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f445', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f446', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f447', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f448', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f449', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f450', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f451', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f452', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f453', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f454', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f455', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f456', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f457', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f458', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f459', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f460', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f461', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f462', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f463', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f464', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f465', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f466', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f467', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f468', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f469', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f470', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f471', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f472', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f473', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f474', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f475', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f476', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f477', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f478', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f479', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f480', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f481', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f482', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f483', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f484', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f485', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f486', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f487', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f488', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f489', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f490', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f491', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f492', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f493', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f494', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f495', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f496', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f497', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f498', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f499', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f500', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f501', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f502', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f503', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f504', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f505', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f506', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f507', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f508', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f509', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f510', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f511', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f512', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f513', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f514', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f515', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f516', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f517', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f518', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f519', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f520', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mom_nhs_num', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mom_pat_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f523', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mom_nnn_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f525', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f526', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f527', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f528', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f529', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f530', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f531', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f532', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ncclocalid1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccstartdate1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccstarttime1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccunitfunction1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestlength1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccdailycount1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccdailycareactivity1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccenddate1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccendtime1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ncclocalid2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccstartdate2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccstarttime2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccunitfunction2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestlength2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccdailycount2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccdailycareactivity2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccenddate2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nccendtime2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f551', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f552', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f553', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f554', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f555', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f556', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f557', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f558', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f559', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f560', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f561', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f562', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f563', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f564', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f565', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f566', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f567', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f568', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f569', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f570', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f571', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f572', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f573', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f574', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f575', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f576', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f577', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f578', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f579', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f580', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f581', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f582', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f583', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f584', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f585', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f586', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f587', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f588', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f589', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f590', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f591', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f592', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f593', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f594', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f595', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f596', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f597', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f598', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f599', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f600', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f601', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f602', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f603', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f604', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f605', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f606', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f607', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f608', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f609', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f610', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f611', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f612', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f613', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f614', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f615', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f616', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f617', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f618', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f619', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f620', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f621', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f622', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f623', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f624', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f625', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f626', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f627', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f628', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f629', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f630', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f631', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f632', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f633', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f634', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f635', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f636', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f637', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f638', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f639', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f640', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f641', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f642', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f643', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f644', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f645', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f646', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f647', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f648', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f649', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f650', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f651', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f652', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f653', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f654', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f655', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f656', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f657', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f658', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f659', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f660', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f661', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f662', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f663', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f664', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f665', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f666', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f667', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f668', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f669', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f670', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f671', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f672', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f673', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f674', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f675', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f676', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f677', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f678', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f679', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f680', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f681', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f682', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f683', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f684', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f685', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f686', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f687', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f688', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f689', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f690', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f691', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f692', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f693', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f694', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f695', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f696', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f697', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f698', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f699', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f700', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f701', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f702', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f703', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f704', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f705', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f706', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f707', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f708', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f709', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f710', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f711', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f712', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f713', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f714', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f715', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f716', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f717', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f718', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f719', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f720', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f721', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f722', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f723', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f724', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_adm_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_disch_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('epi_start_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('epi_end_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f729', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f730', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f731', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f732', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f733', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f734', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('f735', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('datasetref', 'STRING', mode='NULLABLE'),
  
]

table_ref = dataset_ref.table('src_SUS_Airedale_APC_20220601_to_Current')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for src_DemoGraphics_MASTER

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/src_SUS_Airedale_APC_20220601_to_Current.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# Loaded 158279 rows.
